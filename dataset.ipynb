# %%
import pandas as pd

# %%
df = pd.read_csv("data/raw/paysim_full.csv", nrows=1000)

# %%
print(df.columns.tolist())
# Out:
# ['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud', 'isFlaggedFraud']

# %%
print(df.head())
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
print(df['type'].value_counts())
# Out:
# type
# PAYMENT     437
# CASH_OUT    230
# CASH_IN     183
# TRANSFER     99
# DEBIT        51
# Name: count, dtype: int64

# %%
from datetime import datetime, timedelta


start_date = datetime(2026, 1, 1)

df['date'] = pd.to_timedelta(df['step'], unit="hours") + start_date

# %%
print(df[['step', 'date']].head())
# Out:
#    step                date
# 0     1 2026-01-01 01:00:00
# 1     1 2026-01-01 01:00:00
# 2     1 2026-01-01 01:00:00
# 3     1 2026-01-01 01:00:00
# 4     1 2026-01-01 01:00:00
